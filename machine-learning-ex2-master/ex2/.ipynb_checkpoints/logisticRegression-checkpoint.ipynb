# %%
# %config IPCompleter.greedy=True
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ex2data1.txt', header = None)

exams= data.loc[:,0:1]
admit = data.loc[:,2]

plt.scatter(exams[0],exams[1])
plt.xlabel('Exam 1 score')
plt.ylabel('Exam 2 score')
# Out:
# Text(0, 0.5, 'Exam 2 score')
